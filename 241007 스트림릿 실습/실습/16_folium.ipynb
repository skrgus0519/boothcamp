# %% [markdown]
# # 1. folium 설치

# %%
# !pip install folium
# Out:
# ...
# [notice] A new release of pip is available: 24.1.2 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# # 2. 지도 생성하기
#
#
# ```
# import folium
#
# 지도이름 = folium.Map([위도, 경도])
# 지도이름
# ```

# %%
import folium

map = folium.Map([37.526881, 126.934668])
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# #### 지도 비율 조절하기
#
#
# ```
# 지도이름 = folium.Map([위도, 경도], zoom_start=숫자)
# 지도이름
# ```

# %%
import folium

map = folium.Map([37.526881, 126.934668], zoom_start=15)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
# 위도와 경도를 변수에 저장하여 사용하기

# %% [markdown]
# # 3. 지도에 마커 표시하기
#
#
# ```
# folium.Marker([마커 표시 위도, 마커 표시 경도]).add_to(지도이름)
# ```

# %%
map = folium.Map([37.526966, 126.934733], zoom_start=15)
folium.Marker([37.526966, 126.934733]).add_to(map)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# #### 여러 위치에 마커 표시하기
#
# <img src='https://github.com/teacher-jiejie/allinone_AI/blob/images/105_%EC%97%AC%EC%9D%98%EB%8F%84%EA%B3%B5%EC%9B%90.png?raw=true' width=700>

# %%
map = folium.Map([37.526966, 126.934733], zoom_start=15)
folium.Marker([37.526966, 126.934733]).add_to(map)
folium.Marker([37.520230, 126.940010]).add_to(map)
folium.Marker([37.526023, 126.921393]).add_to(map)
folium.Marker([37.515213, 126.938941]).add_to(map)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# #### 마커에 텍스트 표시하기 - 툴팁으로 표현
#
# ```
# folium.Marker([마커 표시 위도, 마커 표시 경도], tooltip='텍스트').add_to(지도이름)
# ```

# %%
map = folium.Map([37.526966, 126.934733], zoom_start=15)
folium.Marker([37.526966, 126.934733], tooltip='여의도 한강공원').add_to(map)
folium.Marker([37.520230, 126.940010], tooltip='63빌딩').add_to(map)
folium.Marker([37.526023, 126.921393], tooltip='여의도 공원').add_to(map)
folium.Marker([37.515213, 126.938941], tooltip='노량진 수산물도매시장').add_to(map)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# #### 마커에 텍스트 표시하기 - 팝업으로 표현
# ```
# folium.Marker([마커 표시 위도, 마커 표시 경도], popup='텍스트').add_to(지도이름)
# ```
#
# popup이나 tooltip에 다음과 같이 html 코드를 삽입하여 이미지를 표기하거나 심지어 YouTube 영상도 삽입할 수 있습니다. (유튜브 영상 - 공유- 퍼가기)

# %%
map = folium.Map([37.526966, 126.934733], zoom_start=15)
folium.Marker([37.526966, 126.934733], popup='여의도 한강공원').add_to(map)
folium.Marker([37.520230, 126.940010], popup='63빌딩').add_to(map)
folium.Marker([37.526023, 126.921393], popup='<iframe width="560" height="315" src="https://www.youtube.com/embed/oXkRuk_6f2A?si=Tzu9OfEv_l0rWpyE" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" referrerpolicy="strict-origin-when-cross-origin" allowfullscreen></iframe>').add_to(map)
folium.Marker([37.515213, 126.938941], popup='노량진 수산물도매시장').add_to(map)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# #### 마커의 색상 변경
# ```
# folium.Marker([마커 표시 위도, 마커 표시 경도], icon = folium.Icon(color='색상명')).add_to(지도이름)
# ```

# %%
map = folium.Map([37.526966, 126.934733], zoom_start=15)
folium.Marker([37.526966, 126.934733], popup='여의도 한강공원', icon = folium.Icon(color='butterfly')).add_to(map)
folium.Marker([37.520230, 126.940010], popup='63빌딩').add_to(map)
folium.Marker([37.526023, 126.921393], popup='<iframe width="560" height="315" src="https://www.youtube.com/embed/oXkRuk_6f2A?si=Tzu9OfEv_l0rWpyE" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" referrerpolicy="strict-origin-when-cross-origin" allowfullscreen></iframe>').add_to(map)
folium.Marker([37.515213, 126.938941], popup='노량진 수산물도매시장').add_to(map)

map
# Out:
# C:\Users\qq\AppData\Local\Temp\ipykernel_11524\443928023.py:2: UserWarning: color argument of Icon should be one of: {'darkgreen', 'lightgreen', 'pink', 'beige', 'gray', 'lightblue', 'cadetblue', 'red', 'darkred', 'white', 'darkpurple', 'lightred', 'lightgray', 'orange', 'purple', 'blue', 'black', 'green', 'darkblue'}.
#   folium.Marker([37.526966, 126.934733], popup='여의도 한강공원', icon = folium.Icon(color='butterfly')).add_to(map)
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
# ...

# %% [markdown]
# #### 마커의 아이콘 표현
# ```
# folium.Marker([마커 표시 위도, 마커 표시 경도], icon = folium.Icon(color='색상명', icon='아이콘모양')).add_to(지도이름)
# ```

# %%
map = folium.Map([37.526966, 126.934733], zoom_start=15)
folium.Marker([37.526966, 126.934733], popup='여의도 한강공원', icon = folium.Icon(color='butterfly')).add_to(map)
folium.Marker([37.520230, 126.940010], popup='63빌딩').add_to(map)
folium.Marker([37.526023, 126.921393], popup='<iframe width="560" height="315" src="https://www.youtube.com/embed/oXkRuk_6f2A?si=Tzu9OfEv_l0rWpyE" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" referrerpolicy="strict-origin-when-cross-origin" allowfullscreen></iframe>').add_to(map)
folium.Marker([37.515213, 126.938941], popup='노량진 수산물도매시장', icon = folium.Icon(color='lightgray', icon='flag')).add_to(map)

map
# Out:
# C:\Users\qq\AppData\Local\Temp\ipykernel_11524\3144951018.py:2: UserWarning: color argument of Icon should be one of: {'darkgreen', 'lightgreen', 'pink', 'beige', 'gray', 'lightblue', 'cadetblue', 'red', 'darkred', 'white', 'darkpurple', 'lightred', 'lightgray', 'orange', 'purple', 'blue', 'black', 'green', 'darkblue'}.
#   folium.Marker([37.526966, 126.934733], popup='여의도 한강공원', icon = folium.Icon(color='butterfly')).add_to(map)
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
# ...

# %% [markdown]
# #### 다양한 마커 아이콘
#
# [https://fontawesome.com/v4.7.0/icons](https://fontawesome.com/v4.7.0/icons)
#
# fontawesome의 아이콘을 사용할 때에는 prefix='fa' 옵션을 추가

# %% [markdown]
# Marker cluster를 통해 군집들 살펴보기

# %%
lat = [37.52860, 37.52400, 37.51865]                         # 위도 리스트  
long = [126.93431, 126.91889, 126.92041]                     # 경도 리스트
names = ['여의도 한강공원', '여의도공원', '샛강생태공원']    # 위치 이름 리스트
icons = ['automobile', 'balance-scale', 'ban']               # 아이콘 모양 리스트   
colors = ['red', 'blue', 'purple']                           # 아이콘 색상 리스트

map_y = folium.Map([lat[0], long[0]], zoom_start = 15)

from folium.plugins import MarkerCluster

marker_cluster = MarkerCluster().add_to(map_y)

map = folium.Map([37.526966, 126.934733], zoom_start=15).add_to(marker_cluster)
folium.Marker([37.526966, 126.934733], popup='여의도 한강공원', icon = folium.Icon(color='butterfly')).add_to(marker_cluster)
folium.Marker([37.520230, 126.940010], popup='63빌딩').add_to(marker_cluster)
folium.Marker([37.526023, 126.921393], popup='<iframe width="560" height="315" src="https://www.youtube.com/embed/oXkRuk_6f2A?si=Tzu9OfEv_l0rWpyE" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" referrerpolicy="strict-origin-when-cross-origin" allowfullscreen></iframe>').add_to(marker_cluster)
folium.Marker([37.515213, 126.938941], popup='노량진 수산물도매시장', icon = folium.Icon(color='lightgray', icon='flag')).add_to(marker_cluster)

map_y
# Out:
# C:\Users\qq\AppData\Local\Temp\ipykernel_11524\3857332523.py:14: UserWarning: color argument of Icon should be one of: {'darkgreen', 'lightgreen', 'pink', 'beige', 'gray', 'lightblue', 'cadetblue', 'red', 'darkred', 'white', 'darkpurple', 'lightred', 'lightgray', 'orange', 'purple', 'blue', 'black', 'green', 'darkblue'}.
#   folium.Marker([37.526966, 126.934733], popup='여의도 한강공원', icon = folium.Icon(color='butterfly')).add_to(marker_cluster)
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
# ...
