# %% [markdown]
# # 네이버 영화 리뷰 데이터 분류

# %% [markdown]
# ### 전처리 과정

# %%
import pandas as pd
import urllib.request

# 데이터셋 다운로드
urllib.request.urlretrieve("https://raw.githubusercontent.com/e9t/nsmc/master/ratings_train.txt", filename="ratings_train.txt")
urllib.request.urlretrieve("https://raw.githubusercontent.com/e9t/nsmc/master/ratings_test.txt", filename="ratings_test.txt")
# Out:
# ('ratings_test.txt', <http.client.HTTPMessage at 0x2d0221e0220>)

# %%
import pandas as pd

train_data = pd.read_table('ratings_train.txt')
test_data = pd.read_table('ratings_test.txt')

# %%
# 영화 리뷰 개수 확인
print('train:', len(train_data))
print('test:', len(test_data))
# Out:
# train: 150000
# test: 50000

# %%
# 상위 5개 출력하여 데이터 확인
train_data.head(10)
# Out:
#          id                                           document  label
# 0   9976970                                아 더빙.. 진짜 짜증나네요 목소리      0
# 1   3819312                  흠...포스터보고 초딩영화줄....오버연기조차 가볍지 않구나      1
# 2  10265843                                  너무재밓었다그래서보는것을추천한다      0
# 3   9045019                      교도소 이야기구먼 ..솔직히 재미는 없다..평점 조정      0
# 4   6483659  사이몬페그의 익살스런 연기가 돋보였던 영화!스파이더맨에서 늙어보이기만 했던 커스틴 ...      1
# 5   5403919      막 걸음마 뗀 3세부터 초등학교 1학년생인 8살용영화.ㅋㅋㅋ...별반개도 아까움.      0
# 6   7797314                              원작의 긴장감을 제대로 살려내지못했다.      0
# 7   9443947  별 반개도 아깝다 욕나온다 이응경 길용우 연기생활이몇년인지..정말 발로해도 그것보단...      0
# 8   7156791                             액션이 없는데도 재미 있는 몇안되는 영화      1
# 9   5912145      왜케 평점이 낮은건데? 꽤 볼만한데.. 헐리우드식 화려함에만 너무 길들여져 있나?      1

# %%
# 라벨의 분포 확인
train_data['label'].value_counts()
# Out:
# label
# 0    75173
# 1    74827
# Name: count, dtype: int64

# %%
# document 열에서 중복인 내용이 있다면 중복 제거
len(train_data['document'].unique())
train_data.drop_duplicates(subset=['document'], inplace=True)

print('제거 후 남은 샘플 수: ', len(train_data))
# Out:
# 제거 후 남은 샘플 수:  146183

# %%
# 데이터 내에 결측치가 있습니다. 찾아서 제거주세요.
# 결측치 확인
print(train_data.isnull().sum())
print(train_data.loc[train_data.document.isnull()])

# 결측치 제거
train_data = train_data.dropna(how = 'any') # Null 값이 존재하는 행 제거

print(len(train_data)) # 146182
# Out:
# id          0
# document    1
# label       0
# dtype: int64
#             id document  label
# 25857  2172111      NaN      1
# 146182

# %% [markdown]
# 한글만 남기고 나머지 데이터 제거

# %%
import numpy as np

train_data['document'] = train_data['document'].str.replace("[^ㄱ-ㅎㅏ-ㅣ가-힣 ]","") # 한글과 공백을 제외하고 모두 제거
train_data['document'] = train_data['document'].str.replace('^ +', "") # 시작 부분의 공백 제거
train_data['document'].replace('', np.nan, inplace=True) # 공백은 Null 값으로 변경
train_data = train_data.dropna(how = 'any') # Null 값 제거
train_data.head(10)
# Out:
# C:\Users\qq\AppData\Local\Temp\ipykernel_13364\4222784049.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   train_data['document'].replace('', np.nan, inplace=True) # 공백은 Null 값으로 변경
#          id                                           document  label
# 0   9976970                                아 더빙.. 진짜 짜증나네요 목소리      0
# 1   3819312                  흠...포스터보고 초딩영화줄....오버연기조차 가볍지 않구나      1
# 2  10265843                                  너무재밓었다그래서보는것을추천한다      0
# 3   9045019                      교도소 이야기구먼 ..솔직히 재미는 없다..평점 조정      0
# 4   6483659  사이몬페그의 익살스런 연기가 돋보였던 영화!스파이더맨에서 늙어보이기만 했던 커스틴 ...      1
# 5   5403919      막 걸음마 뗀 3세부터 초등학교 1학년생인 8살용영화.ㅋㅋㅋ...별반개도 아까움.      0
# 6   7797314                              원작의 긴장감을 제대로 살려내지못했다.      0
# 7   9443947  별 반개도 아깝다 욕나온다 이응경 길용우 연기생활이몇년인지..정말 발로해도 그것보단...      0
# 8   7156791                             액션이 없는데도 재미 있는 몇안되는 영화      1
# 9   5912145      왜케 평점이 낮은건데? 꽤 볼만한데.. 헐리우드식 화려함에만 너무 길들여져 있나?      1

# %%
test_data.drop_duplicates(subset = ['document'], inplace=True) # document 열에서 중복인 내용이 있다면 중복 제거
test_data['document'] = test_data['document'].str.replace("[^ㄱ-ㅎㅏ-ㅣ가-힣 ]","") # 정규 표현식 수행
test_data['document'] = test_data['document'].str.replace('^ +', "") # 시작 부분의 공백 제거
test_data['document'].replace('', np.nan, inplace=True) # 공백은 Null 값으로 변경
test_data = test_data.dropna(how='any') # Null 값 제거
test_data.head(10)
# Out:
# C:\Users\qq\AppData\Local\Temp\ipykernel_13364\1803854010.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   test_data['document'].replace('', np.nan, inplace=True) # 공백은 Null 값으로 변경
#         id                                           document  label
# 0  6270596                                                굳 ㅋ      1
# 1  9274899                               GDNTOPCLASSINTHECLUB      0
# 2  8544678             뭐야 이 평점들은.... 나쁘진 않지만 10점 짜리는 더더욱 아니잖아      0
# 3  6825595                   지루하지는 않은데 완전 막장임... 돈주고 보기에는....      0
# 4  6723715  3D만 아니었어도 별 다섯 개 줬을텐데.. 왜 3D로 나와서 제 심기를 불편하게 하죠??      0
# 5  7898805                                 음악이 주가 된, 최고의 음악영화      1
# 6  6315043                                            진정한 쓰레기      0
# 7  6097171           마치 미국애니에서 튀어나온듯한 창의력없는 로봇디자인부터가,고개를 젖게한다      0
# 8  8932678  갈수록 개판되가는 중국영화 유치하고 내용없음 폼잡다 끝남 말도안되는 무기에 유치한c...      0
# 9  6242223     이별의 아픔뒤에 찾아오는 새로운 인연의 기쁨 But, 모든 사람이 그렇지는 않네..      1

# %%
print('전처리 후 테스트용 샘플의 개수 :',len(train_data))
print('전처리 후 테스트용 샘플의 개수 :',len(test_data))
# Out:
# 전처리 후 테스트용 샘플의 개수 : 146182
# 전처리 후 테스트용 샘플의 개수 : 49157

# %%
# 불용어 지정
stopwords = ['의','가','이','은','들','는','좀','잘','걍','과','도','를','으로','자','에','와','한','하다', 'ㅋ']

# %%
from konlpy.tag import Okt
okt = Okt()

# %%
########## 시간이 많이 소요됩니다 ############
from tqdm import tqdm
X_train = []

# `tqdm`을 사용하여 문장 처리의 진행 상황을 표시합니다.
for sentence in tqdm(train_data['document']):
    # 문장을 형태소 단위로 토큰화, `stem=True`는 형태소의 원형 반환
    tokenized_sentence = okt.morphs(sentence, stem=True)
    
    # 불용어 제거, 불용어 리스트에 포함되지 않은 단어만 남김
    stopwords_removed_sentence = [word for word in tokenized_sentence if not word in stopwords]
    
    # 불용어가 제거된 단어 리스트
    X_train.append(stopwords_removed_sentence)

# 최종적으로, `X_train` 리스트에는 전처리된 문장들이 토큰화되고 불용어가 제거된 형태로 저장됩니다.
# Out:
# 100%|██████████| 146182/146182 [09:03<00:00, 269.07it/s]

# %%
########## 시간이 많이 소요됩니다 ############
X_test = []
for sentence in tqdm(test_data['document']):
    tokenized_sentence = okt.morphs(sentence, stem=True) # 토큰화
    stopwords_removed_sentence = [word for word in tokenized_sentence if not word in stopwords] # 불용어 제거
    X_test.append(stopwords_removed_sentence)
# Out:
# 100%|██████████| 49157/49157 [03:16<00:00, 249.55it/s]

# %%
print('전처리 후 테스트용 샘플의 개수 :',len(X_test))
# Out:
# 전처리 후 테스트용 샘플의 개수 : 49157

# %%
X_train_new = X_train
X_test_new = X_test

# %%
#X_train = X_train_new
#X_test = X_test_new

# %%
from tensorflow.keras.preprocessing.text import Tokenizer

# 단어 집합 생성
tokenizer = Tokenizer()
tokenizer.fit_on_texts(X_train)

# %%
print(tokenizer.word_index)
# Out:
# {'.': 1, '영화': 2, '보다': 3, '..': 4, '을': 5, '...': 6, ',': 7, '없다': 8, '이다': 9, '있다': 10, '좋다': 11, '너무': 12, '?': 13, '다': 14, '정말': 15, '되다': 16, '재밌다': 17, '적': 18, '만': 19, '같다': 20, '진짜': 21, '!': 22, '로': 23, '점': 24, '아니다': 25, '않다': 26, '에서': 27, '만들다': 28, '연기': 29, '나오다': 30, '것': 31, '평점': 32, '내': 33, '~': 34, '최고': 35, '그': 36, '나': 37, '안': 38, '인': 39, '스토리': 40, '생각': 41, '못': 42, '....': 43, '왜': 44, '드라마': 45, '게': 46, '감동': 47, '사람': 48, '1': 49, '보고': 50, '이렇다': 51, '말': 52, '고': 53, '아깝다': 54, '더': 55, '아': 56, '때': 57, '배우': 58, 'ㅋㅋ': 59, '거': 60, '감독': 61, '그냥': 62, '재미있다': 63, '요': 64, '내용': 65, '재미': 66, '중': 67, '뭐': 68, '까지': 69, '!!': 70, '주다': 71, '자다': 72, '하고': 73, '지루하다': 74, '재미없다': 75, '시간': 76, '수': 77, '쓰레기': 78, '가다': 79, '네': 80, '모르다': 81, '들다': 82, '그렇다': 83, '싶다': 84, '지': 85, '작품': 86, '10': 87, '사랑': 88, '알다': 89, '하나': 90, '다시': 91, '마지막': 92, '볼': 93, '이건': 94, '오다': 95, '저': 96, '정도': 97, '완전': 98, '2': 99, 'ㅋㅋㅋ': 100, '많다': 101, '처음': 102, '장면': 103, '액션': 104, '주인공': 105, '차다': 106, '이렇게': 107, '걸': 108, '안되다': 109, '개': 110, '나다': 111, 'ㅠㅠ': 112, '3': 113, "'": 114, '지금': 115, '돈': 116, '최악': 117, '이야기': 118, '임': 119, '하': 120, '느낌': 121, '넘다': 122, '연출': 123, '라': 124, '끝': 125, '듯': 126, '인데': 127, '대': 128, '명작': 129, '좋아하다': 130, '그리고': 131, '별': 132, '별로': 133, '역시': 134, '받다': 135, '기': 136, '많이': 137, '남다': 138, '난': 139, '이해': 140, '^^': 141, 'ㅡㅡ': 142, '이영화': 143, '면': 144, '이런': 145, '라고': 146, '괜찮다': 147, '!!!': 148, '또': 149, '느끼다': 150, '버리다': 151, '이나': 152, '여자': 153, '때문': 154, '서': 155, '성': 156, '부터': 157, '먹다': 158, '아름답다': 159, '해주다': 160, '꼭': 161, '편': 162, '이고': 163, '전': 164, '보기': 165, '두': 166, '일': 167, '여': 168, '무슨': 169, '기억': 170, '에게': 171, '엔': 172, '결말': 173, '야': 174, '랑': 175, '짱': 176, 'ㅎㅎ': 177, '아쉽다': 178, '마음': 179, '인생': 180, '소재': 181, 'ㅠ': 182, '~~': 183, '뻔하다': 184, '끄다': 185, '애': 186, '어떻다': 187, '보여주다': 188, '님': 189, '없이': 190, '수준': 191, '어리다': 192, '영': 193, '무섭다': 194, '현실': 195, '맞다': 196, '씨': 197, '한번': 198, '속': 199, '가장': 200, '반전': 201, '급': 202, '재다': 203, '제': 204, '웃기다': 205, '라는': 206, '전개': 207, '매력': 208, ';;': 209, '되어다': 210, '??': 211, '남자': 212, '한국': 213, '끝나다': 214, '뿐': 215, '본': 216, '가슴': 217, '늘다': 218, '낮다': 219, '말다': 220, '슬프다': 221, '죽다': 222, '음악': 223, '높다': 224, '유치하다': 225, '아이': 226, '알': 227, '다른': 228, '멋지다': 229, '니': 230, '원작': 231, '줄': 232, '인간': 233, '하지만': 234, '솔직하다': 235, '우리': 236, '쓰다': 237, '크다': 238, '추천': 239, '냐': 240, '눈물': 241, '인지': 242, '살다': 243, '모든': 244, '함': 245, '화': 246, '내다': 247, '번': 248, '자체': 249, '야하다': 250, '눈': 251, '허다': 252, '지만': 253, '찍다': 254, '인가': 255, '캐릭터': 256, '코미디': 257, '보이다': 258, '처럼': 259, 'ㅋㅋㅋㅋ': 260, '움': 261, '뭔가': 262, '대한': 263, '건지다': 264, '모두': 265, '이상': 266, '전혀': 267, '대박': 268, '돼다': 269, '연기력': 270, '이쁘다': 271, '이네': 272, '여운': 273, '지다': 274, '미치다': 275, '그래도': 276, '기대': 277, '개봉': 278, '짜증나다': 279, '근데': 280, '공감': 281, '일본': 282, '중간': 283, '기대하다': 284, '영상': 285, '표현': 286, '아주': 287, ')': 288, '(': 289, '부분': 290, '시리즈': 291, '모습': 292, '계속': 293, '에는': 294, '제목': 295, '분': 296, '이랑': 297, '-': 298, '귀엽다': 299, '시키다': 300, '가족': 301, '작': 302, '내내': 303, '치다': 304, ';': 305, '이라': 306, '후': 307, 'ㅎ': 308, '뭔': 309, '보지': 310, '믿다': 311, 'oo': 312, '진심': 313, '몰입': 314, '실망': 315, '밖에': 316, '기분': 317, '대단하다': 318, '작가': 319, 'ㅜㅜ': 320, '잔잔하다': 321, '떨어지다': 322, '위': 323, '이제': 324, '건': 325, '""': 326, ',,': 327, '웃다': 328, '공포': 329, '요즘': 330, '스릴러': 331, '빠지다': 332, '감': 333, '이라는': 334, '용': 335, '개인': 336, '긴장감': 337, '잼': 338, 'ㅡ': 339, '대사': 340, '4': 341, '조금': 342, '짜다': 343, '굿': 344, '점도': 345, '애니': 346, '이유': 347, '제대로': 348, '삶': 349, '특히': 350, '알바': 351, '노래': 352, '울다': 353, '극장': 354, '욕': 355, '딱': 356, '한테': 357, '점수': 358, '시작': 359, '잇다': 360, '막장': 361, '연': 362, '오랜': 363, '0': 364, '나름': 365, '이상하다': 366, '이란': 367, '시': 368, '.....': 369, '깊다': 370, '예쁘다': 371, '이지': 372, '극': 373, '차라리': 374, '제일': 375, ...

# %%
print(tokenizer.word_counts.items())
# Out:
# odict_items([('아', 4359), ('더빙', 573), ('..', 28928), ('진짜', 8317), ('짜증나다', 1008), ('목소리', 374), ('흠', 259), ('...', 22611), ('포스터', 573), ('보고', 4637), ('초딩', 422), ('영화', 50461), ('줄', 1240), ('....', 5177), ('오버', 142), ('연기', 6432), ('조차', 242), ('가볍다', 361), ('않다', 7714), ('너', 686), ('무재', 69), ('밓었', 1), ('다그', 24), ('래서', 17), ('보다', 41094), ('추천', 1187), ('다', 10188), ('교도소', 16), ('이야기', 2171), ('구먼', 11), ('솔직하다', 1204), ('재미', 3888), ('없다', 15568), ('평점', 6275), ('조정', 40), ('사이', 219), ('몬페', 2), ('그', 5669), ('익살스럽다', 9), ('돋보이다', 288), ('!', 8288), ('스파이더맨', 63), ('에서', 6990), ('늙다', 197), ('보이다', 1071), ('커스틴', 4), ('던스트', 2), ('너무나도', 206), ('이쁘다', 1033), ('막', 330), ('걸음', 20), ('마', 238), ('떼다', 151), ('3', 2233), ('세', 632), ('부터', 1697), ('초등학교', 116), ('1', 4733), ('학년', 122), ('생인', 5), ('8', 535), ('살다', 1169), ('.', 67405), ('ㅋㅋㅋ', 2459), ('별', 2010), ('반개', 211), ('아깝다', 4402), ('움', 1055), ('원작', 1252), ('긴장감', 830), ('을', 23183), ('제대로', 799), ('살리다', 533), ('욕', 790), ('나오다', 6397), ('이응경', 8), ('길용우', 4), ('연', 765), ('기', 1951), ('생활', 126), ('몇', 700), ('년', 388), ('인지', 1174), ('정말', 9738), ('발', 322), ('로', 7845), ('해도', 440), ('그것', 445), ('보단', 509), ('낫다', 544), ('납치', 49), ('감금', 11), ('만', 8608), ('반복', 151), ('드라마', 5045), ('가족', 940), ('못', 5296), ('사람', 4835), ('모', 349), ('엿', 205), ('네', 3234), ('액션', 2394), ('있다', 12414), ('안되다', 2315), ('왜케', 130), ('낮다', 1315), ('?', 11009), ('꽤', 492), ('볼', 2743), ('데', 649), ('헐리우드', 143), ('식', 705), ('화려하다', 368), ('너무', 11106), ('길들이다', 20), ('인피니트', 27), ('짱', 1548), ('이다', 13174), ('♥', 693), ('볼때', 326), ('마다', 674), ('눈물나다', 174), ('죽다', 1289), ('90년', 239), ('대의', 206), ('향수', 66), ('자극', 271), ('!!', 3716), ('허진호', 6), ('감성', 420), ('절제', 67), ('멜로', 297), ('달인', 21), ('~', 5966), ('울면', 78), ('서', 1714), ('손', 278), ('고', 4499), ('횡단보도', 1), ('건너다', 8), ('때', 4320), ('뛰다', 171), ('치다', 937), ('올', 248), ('뻔', 318), ('이범수', 39), ('드럽다', 235), ('담백하다', 68), ('깔끔하다', 174), ('좋다', 11992), ('신', 555), ('문', 177), ('사', 332), ('로만', 138), ('자꾸', 263), ('잊어버리다', 15), ('것', 6299), ('취향', 274), ('존중', 36), ('다지', 15), ('내생', 106), ('극장', 792), ('중', 3811), ('가장', 1393), ('노잼', 741), ('노', 224), ('감동', 4842), ('임', 2118), ('스토리', 5341), ('어거지', 76), ('ㄱ', 118), ('냥', 140), ('매번', 65), ('긴장', 155), ('되다', 8839), ('재밋음', 84), ('ㅠㅠ', 2253), ('차다', 2331), ('웃기다', 1371), ('바스코', 14), ('이기', 171), ('면', 1819), ('락스', 13), ('코', 401), ('라고', 1805), ('끄다', 1495), ('바비', 24), ('아이돌', 150), ('이라고', 691), ('깔다', 210), ('그냥', 4100), ('안달', 22), ('난', 1926), ('처럼', 1064), ('굿바이', 20), ('레닌', 6), ('표절', 182), ('인', 5473), ('이해', 1903), ('왜', 5152), ('뒤', 537), ('갈수록', 512), ('없어지다', 135), ('이건', 2675), ('깨알', 68), ('캐스팅', 573), ('질퍽', 3), ('하', 2115), ('지', 2966), ('산뜻하다', 14), ('내', 5972), ('용구성', 6), ('자다', 3610), ('버무러진', 2), ('일드', 37), ('약탈', 4), ('위', 874), ('변명', 29), (',', 17627), ('이르다', 402), ('저', 2577), ('놈', 741), ('착하다', 216), ('절대', 721), ('아니다', 7785), ('걸', 2326), ('요', 4004), ('나름', 760), ('심오하다', 100), ('뜻', 174), ('듯', 2035), ('학생', 132), ('선생', 64), ('놀다', 106), ('웃다', 855), ('건', 866), ('불가능하다', 48), ('재미없다', 3475), ('지루하다', 3506), ('같다', 8337), ('음식', 82), ('인데', 2029), ('바베트', 2), ('만찬', 9), ('하고', 3575), ('넘다', 2089), ('차이나다', 10), (';', 936), ('게', 4940), ('별로', 2003), ('안', 5489), ('핀란드', 8), ('풍경', 120), ('이라도', 398), ('구', 568), ('경', 127), ('할랫', 1), ('늘다', 1316), ('ㅡㅡ', 1836), ('평범하다', 300), ('수작', 659), ('이라', 929), ('는걸', 176), ('말씀드리다', 7), ('주제', 379), ('중반', 286), ('짤랐을꺼', 1), ('야', 1567), ('그래서', 481), ('납득', 55), ('수', 3420), ('그렇다', 3099), ('꼭', 1631), ('kl', 1), ('2', 2485), ('g', 26), ('고추', 15), ('털다', 27), ('버리다', 1772), ('카밀라', 10), ('벨', 49), ('발연기', 441), ('재밋는뎅', 1), ('센스', 79), ('연출', 2081), ('력', 707), ('탁월하다', 66), ('9', 501), ('점', 7842), ('엄포스', 2), ('위력', 12), ('다시', 2835), ('한번', 1403), ('깨닫다', 148), ('해주다', 1642), ('적', 8733), ('남', 641), ('꽃', 91), ('검사', 55), ('님', 1463), ('완전', 2528), ('명품', 135), (' ...

# %% [markdown]
# 사용되는 단어 수가 지나치게 많아 보임 -> 줄일 필요 있음

# %%
threshold = 3
total_cnt = len(tokenizer.word_index) # 단어의 수
rare_cnt = 0 # 등장 빈도수가 threshold보다 작은 단어의 개수를 카운트
total_freq = 0 # 훈련 데이터의 전체 단어 빈도수 총 합
rare_freq = 0 # 등장 빈도수가 threshold보다 작은 단어의 등장 빈도수의 총 합

# 단어와 빈도수의 쌍(pair)을 key와 value로 받는다.
for key, value in tokenizer.word_counts.items():
    total_freq = total_freq + value

    # 단어의 등장 빈도수가 threshold보다 작으면
    if(value < threshold):
        rare_cnt = rare_cnt + 1
        rare_freq = rare_freq + value

print('단어 집합(vocabulary)의 크기 :',total_cnt)
print('등장 빈도가 %s번 이하인 희귀 단어의 수: %s'%(threshold - 1, rare_cnt))
print("단어 집합에서 희귀 단어의 비율:", (rare_cnt / total_cnt)*100)
print("전체 등장 빈도에서 희귀 단어 등장 빈도 비율:", (rare_freq / total_freq)*100)
# Out:
# 단어 집합(vocabulary)의 크기 : 49585
# 등장 빈도가 2번 이하인 희귀 단어의 수: 28787
# 단어 집합에서 희귀 단어의 비율: 58.05586366844812
# 전체 등장 빈도에서 희귀 단어 등장 빈도 비율: 1.9119459785408355

# %%
# 단어수 결정(전체 - 빈도수 2이하의 수 + padding(1))
vocab_size = total_cnt - rare_cnt + 1
print('단어 집합의 크기 :',vocab_size)
# Out:
# 단어 집합의 크기 : 20799

# %%
tokenizer = Tokenizer(vocab_size) # 빈도수 2 이하인 단어는 제거
tokenizer.fit_on_texts(X_train)
X_train = tokenizer.texts_to_sequences(X_train)
X_test = tokenizer.texts_to_sequences(X_test)

# %%
y_train = np.array(train_data['label'])
y_test = np.array(test_data['label'])

# %%
# 학습용 데이터와 라벨 개수 확인
print(len(X_train))
print(len(y_train))

# 단어가 정수로 변환된 것 확인
print(X_train[:5])
# Out:
# 146182
# 146182
# [[56, 486, 4, 21, 279, 703], [962, 6, 487, 50, 648, 2, 232, 43, 1528, 29, 1012, 721, 26], [404, 2571, 5302, 6618, 3, 239, 14], [6851, 118, 8575, 4, 235, 66, 8, 4, 32, 3794], [1097, 36, 9661, 29, 879, 2, 22, 2736, 27, 1174, 258, 15125, 1140, 271, 258]]

# %% [markdown]
# 빈도수가 낮은 데이터를 제거하며, 빈 행이 생길 가능성이 있음

# %%
# 빈도수가 낮은 단어로만 구성된 행은 빈 샘플이 되었을 수 있음(길이가 1미만인 행 찾기)
drop_train = [index for index, sentence in enumerate(X_train) if len(sentence) < 1]
drop_test = [index for index, sentence in enumerate(X_test) if len(sentence) < 1]

# %%
# 빈 샘플 확인
print(len(drop_train))
print(len(drop_test))
# Out:
# 307
# 134

# %%
# X_train 빈 샘플들을 제거
X_train = np.delete(X_train, drop_train, axis=0)
y_train = np.delete(y_train, drop_train, axis=0)
X_test = np.delete(X_test, drop_test, axis=0)
y_test = np.delete(y_test, drop_test, axis=0)

# %%
# 빈 샘플 제거 후 길이 확인
print(len(X_train), len(X_test))
print(len(y_train), len(y_test))
# Out:
# 145875 49023
# 145875 49023

# %%
import matplotlib as plt

print('리뷰의 최대 길이 :',max(len(l) for l in X_train))
print('리뷰의 평균 길이 :',sum(map(len, X_train))/len(X_train))
#plt.hist([len(s) for s in X_train], bins=50)
#plt.xlabel('length of samples')
#plt.ylabel('number of samples')
#plt.show()
# Out:
# 리뷰의 최대 길이 : 36
# 리뷰의 평균 길이 : 36.0

# %%
# 95%의 데이터를 포함하는 샘플의 길이 결정
lengths = []

for x in X_train:
    length = len(x)
    lengths.append(length)

max_len = int(np.percentile(lengths, 95))
print(max_len)
# Out:
# 36

# %%
# padding, 전체 데이터의 길이를 max_len 으로 맞춘다
from tensorflow.keras.preprocessing.sequence import pad_sequences

X_train = pad_sequences(X_train, maxlen = max_len)
X_test = pad_sequences(X_test, maxlen = max_len)

# %% [markdown]
# # 2. LSTM으로 네이버 영화 리뷰 감성 분류하기

# %%
# 콜백 생성
from tensorflow.keras.callbacks import ModelCheckpoint

mc = ModelCheckpoint('best_model_naver_movie.keras', monitor='val_loss', mode='min', verbose=1, save_best_only=True)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, Dense, Flatten, Dense

# 모델 생성 및 컴파일
model = Sequential()
model.add(Embedding())
model.add(Flatten())
model.add(Dense(1, activation='softmax'))

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['acc'])

# %%
# 모델 학습
model.fit(X_train, y_train, epochs=5, batch_size=128, validation_split=0.2, callbacks=[mc])
# Out:
# Epoch 1/5
# 897/912 ━━━━━━━━━━━━━━━━━━━━ 0s 852us/step - acc: 0.4972 - loss: 0.0000e+00
# Epoch 1: val_loss improved from inf to 0.00000, saving model to best_model_naver_movie.keras
# 912/912 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - acc: 0.4972 - loss: 0.0000e+00 - val_acc: 0.4962 - val_loss: 0.0000e+00
# Epoch 2/5
# 849/912 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - acc: 0.4987 - loss: 0.0000e+00
# Epoch 2: val_loss did not improve from 0.00000
# 912/912 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - acc: 0.4986 - loss: 0.0000e+00 - val_acc: 0.4962 - val_loss: 0.0000e+00
# Epoch 3/5
# 856/912 ━━━━━━━━━━━━━━━━━━━━ 0s 772us/step - acc: 0.4983 - loss: 0.0000e+00
# Epoch 3: val_loss did not improve from 0.00000
# 912/912 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - acc: 0.4983 - loss: 0.0000e+00 - val_acc: 0.4962 - val_loss: 0.0000e+00
# Epoch 4/5
# 850/912 ━━━━━━━━━━━━━━━━━━━━ 0s 779us/step - acc: 0.4998 - loss: 0.0000e+00
# Epoch 4: val_loss did not improve from 0.00000
# 912/912 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - acc: 0.4997 - loss: 0.0000e+00 - val_acc: 0.4962 - val_loss: 0.0000e+00
# Epoch 5/5
# 863/912 ━━━━━━━━━━━━━━━━━━━━ 0s 781us/step - acc: 0.4998 - loss: 0.0000e+00
# Epoch 5: val_loss did not improve from 0.00000
# 912/912 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - acc: 0.4998 - loss: 0.0000e+00 - val_acc: 0.4962 - val_loss: 0.0000e+00

# %%
# 정확도 평가
result = model.evaluate(X_test, y_test)

print("\n테스트 손실: %.4f" % (result[0]))
print("테스트 정확도: %.4f" % (result[1]))
# Out:
# 1532/1532 ━━━━━━━━━━━━━━━━━━━━ 1s 716us/step - acc: 0.5041 - loss: 0.0000e+00
#
# 테스트 손실: 0.0000
# 테스트 정확도: 0.5027

# %% [markdown]
# # 저장된 가중치 불러와서 리뷰 예측해보기

# %%
loaded_model = load_model('best_model_naver_movie.keras')
print("\n 테스트 정확도: %.4f" % (loaded_model.evaluate(X_test, y_test)[1]))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[118], line 1
# ----> 1 loaded_model = load_model('best_model_naver_movie.keras')
#       2 print("\n 테스트 정확도: %.4f" % (loaded_model.evaluate(X_test, y_test)[1]))
#
# NameError: name 'load_model' is not defined

# %%
import re
def sentiment_predict(new_sentence):
  new_sentence = re.sub(r'[^ㄱ-ㅎㅏ-ㅣ가-힣 ]','', new_sentence)
  new_sentence = okt.morphs(new_sentence, stem=True) # 토큰화
  new_sentence = [word for word in new_sentence if not word in stopwords] # 불용어 제거
  encoded = tokenizer.texts_to_sequences([new_sentence]) # 정수 인코딩
  pad_new = pad_sequences(encoded, maxlen = max_len) # 패딩
  score = float(loaded_model.predict(pad_new)) # 예측
  if(score > 0.5):
    print("{:.2f}% 확률로 긍정 리뷰입니다.\n".format(score * 100))
  else:
    print("{:.2f}% 확률로 부정 리뷰입니다.\n".format((1 - score) * 100))

# %%
sentiment_predict('이 영화 개꿀잼 ㅋㅋㅋ')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[112], line 1
# ----> 1 sentiment_predict('이 영화 개꿀잼 ㅋㅋㅋ')
#
# Cell In[111], line 8, in sentiment_predict(new_sentence)
#       6 encoded = tokenizer.texts_to_sequences([new_sentence]) # 정수 인코딩
#       7 pad_new = pad_sequences(encoded, maxlen = max_len) # 패딩
# ----> 8 score = float(loaded_model.predict(pad_new)) # 예측
#       9 if(score > 0.5):
#      10   print("{:.2f}% 확률로 긍정 리뷰입니다.\n".format(score * 100))
#
# NameError: name 'loaded_model' is not defined

# %%
sentiment_predict('이 영화 핵노잼 ㅠㅠ')
